# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.api import VAR
from statsmodels.tsa.arima.model import ARIMA
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale

# %%
# load data
descriptions = pd.read_excel('DatiProject.xlsx', sheet_name=3)
raw_standard_vars = pd.read_excel('DatiProject.xlsx', sheet_name=0)

# %%
# create new columns for needed transformed variables
raw_standard_vars['log_gdp'] = np.log(raw_standard_vars['GDPC1'])
raw_standard_vars['log_cpi'] = np.log(raw_standard_vars['PCECTPI'])
raw_standard_vars['inflation'] = raw_standard_vars['log_cpi'].diff().fillna(0)
raw_standard_vars['tspread'] = raw_standard_vars['GS10'] - raw_standard_vars['TB3MS']
raw_standard_vars['diff_log_gdp'] = raw_standard_vars['log_gdp'].diff().fillna(0)

# %% [markdown]
# ## Section 1

# %%
vars_1 = ['log_gdp', 'diff_log_gdp', 'log_cpi', 'inflation', 'tspread']
titles_vars_1 = [r'$\log(GDP_t)$', r'$\Delta \log(GDP_t)$', r'$\log(CPI_t)$', r'$Inflation(\pi_t)$', r'$T spread_t$']

def plot_series(data, vars, titles):
    for v, title in zip(vars, titles):
        sns.set_theme()
        sns.lineplot(data=data, y=v, x='Time')
        plt.title(title)
        plt.ylabel('')
        plt.show()

plot_series(raw_standard_vars, vars_1, titles_vars_1)

# %% [markdown]
# ## Section 2

# %%
sample_1 = raw_standard_vars[(raw_standard_vars['Time'] < '1985-07-01') & (raw_standard_vars['Time'] > '1960-07-10')].reset_index(drop=True)

columns_autocorr = ['inflation', 'tspread', 'diff_log_gdp']
titles_autocorr = [ r'$Inflation(\pi)$', r'$T spread$', r'$\Delta \log(GDP)$' ]

for column, title in zip(columns_autocorr, titles_autocorr):
    ts = sample_1[column]
    plot_acf(ts, bartlett_confint=False)
    plt.title(f'Autocorrelation of {title}')
    plt.xlabel("Lag")
    plt.ylabel("Autocorrelation")
    plt.show()

# %%
columns_autocorr = ['inflation', 'tspread', 'diff_log_gdp']
titles_autocorr = [ r'$Inflation(\pi)$', r'$T spread$', r'$\Delta \log(GDP)$' ]

for column, title in zip(columns_autocorr, titles_autocorr):
    ts = sample_1[column]
    plot_pacf(ts)
    plt.title(f'Partial Autocorrelation of {title}')
    plt.xlabel("Lag")
    plt.ylabel("Partial Autocorrelation")
    plt.show()

# %% [markdown]
# Find p for Var(p) models through AIC

# %%
model_vars = sample_1[['diff_log_gdp', 'inflation', 'tspread']]
ps = range(1, 25)
aics = []
for p in ps:
    # Create VAR model
    model = VAR(model_vars)
    # Fit the model with the chosen lag order
    results = model.fit(p)
    aics.append(abs(results.aic))

i = np.argmin(aics)
p_min = i + 1
aic_min = aics[i]

print(p_min, aic_min)
# Out:
# 1 21.52242321928951

# %%
sns.lineplot(y=aics, x=list(ps), marker='o')
plt.xlabel('lag order (p)')
plt.ylabel('AIC')
plt.title('AIC values for different VAR(p) models')
plt.axhline(aic_min, color='red', linestyle='--', linewidth=1)

# %%
var1 = VAR(model_vars)
results_var1 = model.fit(1)
results_var1.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 10, Dec, 2023
# Time:                     00:15:15
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                   -21.2079
# Nobs:                     99.0000    HQIC:                  -21.3952
# Log likelihood:           655.935    FPE:                4.49767e-10
# AIC:                     -21.5224    Det(Omega_mle):     3.99376e-10
# --------------------------------------------------------------------
# Results for equation diff_log_gdp
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.009531         0.002572            3.706           0.000
# L1.diff_log_gdp         0.133974         0.096090            1.394           0.163
# L1.inflation           -0.362962         0.142447           -2.548           0.011
# L1.tspread              0.002283         0.000877            2.603           0.009
# ==================================================================================
#
# Results for equation inflation
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.001343         0.000872            1.540           0.124
# L1.diff_log_gdp         0.030362         0.032590            0.932           0.352
# L1.inflation            0.894823         0.048313           18.521           0.000
# L1.tspread             -0.000359         0.000297           -1.207           0.227
# ==================================================================================
#
# Results for equation tspread
# ==================================================================================
#                      coefficient       std. error           t-stat            prob
# ----------------------------------------------------------------------------------
# const                   0.374669         0.178181            2.103           0.035
# L1.diff_log_gdp       -10.247378         6.657457           -1.539           0.124
# L1.inflation           -7.618371         9.869213           -0.772           0.440
# L1.tspread              0.829924         0.060754           13.660           0.000
# ==================================================================================
#
# Correlation matrix of residuals
#                 diff_log_gdp  inflation   tspread
# diff_log_gdp        1.000000   0.040588 -0.237026
# inflation           0.040588   1.000000 -0.109285
# tspread            -0.237026  -0.109285  1.000000

# %%
residuals_var1 = results_var1.resid
residuals_var1['Time'] = sample_1['Time']
residuals_var1.head()
# Out:
#    diff_log_gdp  inflation   tspread       Time
# 1      0.013502  -0.004896  0.016308 1960-12-30
# 2     -0.018838   0.002211  0.620706 1961-03-30
# 3     -0.004936  -0.001555  0.031433 1961-06-30
# 4     -0.025086  -0.000002  0.061602 1961-09-30
# 5     -0.003099  -0.002430 -0.348396 1961-12-30

# %%
residuals_col = ['diff_log_gdp', 'inflation', 'tspread']
residuals_titles = [r'$\Delta \log(GDP)$', r'$Inflation(\pi)$', r'$T spread$' ]
for residual, title in zip(residuals_col, residuals_titles):
    sns.lineplot(data=residuals_var1, y=residual, x = 'Time')
    plt.title(f'Residuals of VAR(1) model for {title}')
    plt.show()

# %%
col_res_parcorr = ['inflation', 'tspread', 'diff_log_gdp', ]
titles_res_parcorr = [ r'$Inflation\:(\pi)$', r'$T spread$', r'$\Delta \log(GDP)$' ]

for column, title in zip(col_res_parcorr, titles_res_parcorr):
    ts = residuals_var1[column]
    plot_acf(ts, bartlett_confint=False)
    plt.title(f'Autocorrelation of residuals - {title}')
    plt.xlabel("Lag")
    plt.ylabel("Autocorrelation")
    plt.show()

# %%
col_res_parcorr = ['inflation', 'tspread', 'diff_log_gdp', ]
titles_res_parcorr = [ r'$Inflation\:(\pi)$', r'$T spread$', r'$\Delta \log(GDP)$' ]

for column, title in zip(col_res_parcorr, titles_res_parcorr):
    ts = residuals_var1[column]
    plot_pacf(ts)
    plt.title(f'Partial Autocorrelation of residuals - {title}')
    plt.xlabel("Lag")
    plt.ylabel("Partial Autocorrelation")
    plt.show()

# %% [markdown]
# ## Section 3

# %%
raw_factors = pd.read_excel('DatiProject.xlsx', sheet_name=1)
sample_1_factors_with_time = raw_factors[(raw_factors['Time'] < '1985-07-01') & (raw_factors['Time'] > '1960-07-10')].reset_index(drop=True)
sample_1_factors = sample_1_factors_with_time.drop(['Time'], axis=1)
sample_1_factors =(sample_1_factors-sample_1_factors.mean())/sample_1_factors.std()
sample_1_factors = pd.concat([sample_1_factors_with_time["Time"], sample_1_factors], axis=1).reset_index(drop=True)

# %%
np.set_printoptions(suppress=True)
pca = PCA(n_components=10)
pccomps = pca.fit_transform(sample_1_factors.drop('Time', axis=1))

# %%
sns.lineplot(y = pca.explained_variance_ratio_, x = list(range(1,11)), marker="o")
plt.xticks([x for x in range(1, 11)])
plt.title("Scree Plot - Explained Variance by each PC")
plt.xlabel("Component Number")
plt.ylabel("Explained Variance")
plt.axhline(pca.explained_variance_ratio_[2], color='red', linestyle='--', linewidth=1)

# %%
# most important factors for first principal component
factor_importance_df = pd.DataFrame({
    'ID': list(range(1,246)),
    'Loading': abs(pca.components_[0])
})

factor_importance_df = factor_importance_df.sort_values('Loading', ascending=False)
factor_importance_df = factor_importance_df.set_index('ID').join(descriptions.set_index('ID'))

factor_importance_df.head(50)

# TODO: Actually he asks us to plot it
# Out:
#       Loading SW ID  TCODE  SW Factors     FRED MNEMONIC  \
# ID
# 38   0.124695    38    5.0         0.0            SRVPRD
# 20   0.124055    20    5.0         0.0             OUTBS
# 36   0.122826    36    5.0         0.0            USPRIV
# 35   0.122780    35    5.0         0.0            PAYEMS
# 21   0.122346    21    5.0         0.0             OUTMS
# 58   0.121744    58    2.0         0.0           CIVPART
# 34   0.121553    34    1.0         1.0            CUMFNS
# 191  0.121443  n.a.    2.0         0.0   B021RE1Q156NBEA
# 62   0.120962    62    2.0         1.0       LNS14000012
# 39   0.120586    39    5.0         0.0            USGOOD
# 68   0.116832    68    5.0         1.0          UEMP27OV
# 59   0.116818    59    2.0         0.0            UNRATE
# 22   0.116771    22    5.0         0.0            INDPRO
# 75   0.116465    75    5.0         0.0             HOAMS
# 180  0.114396   191    5.0         1.0         SPCS10RSA
# 87   0.113693    87    5.0         1.0            HOUSTW
# 24   0.113157    24    5.0         0.0           IPCONGD
# 30   0.112891    30    5.0         1.0          IPNCONGD
# 40   0.111805    40    5.0         1.0           DMANEMP
# 74   0.111771    74    5.0         0.0             HOABS
# 6    0.111109     6    5.0         0.0            GPDIC1
# 7    0.111009     7    5.0         0.0              FPIx
# 73   0.110607    73    5.0         1.0       LNS12032194
# 8    0.110450     8    5.0         1.0  Y033RC1Q027SBEAx
# 217  0.109873  n.a.    6.0         0.0       DTCOLNVHFNM
# 49   0.108829    49    5.0         1.0            USMINE
# 25   0.108710    25    5.0         0.0             IPMAT
# 63   0.108450    63    2.0         1.0       LNS14000025
# 177  0.108330   188    5.0         1.0        TFAABSHNOx
# 18   0.107384    18    5.0         0.0            DPIC96
# 45   0.107153    45    5.0         1.0            USINFO
# 19   0.106189    19    5.0         0.0            OUTNFB
# 46   0.105778    46    5.0         1.0             USPBS
# 65   0.104173    65    5.0         1.0           UEMPLT5
# 26   0.104160    26    5.0         1.0            IPDMAT
# 51   0.103335    51    5.0         0.0            USGOVT
# 37   0.103164    37    5.0         0.0            MANEMP
# 66   0.102653    66    5.0         1.0         UEMP5TO14
# 56   0.102480    56    5.0         1.0     CES9093000001
# 89   0.097360    90    5.0         1.0            RSAFSx
# 72   0.096061    72    5.0         1.0       LNS13023569
# 23   0.096024    23    5.0         0.0           IPFINAL
# 41   0.095645    41    5.0         0.0          NDMANEMP
# 5    0.095410     5    5.0         1.0             PCNDx
# 78   0.095114    78    2.0         1.0          AWHNONAG
# 52   0.094915    52    5.0         1.0           USTRADE
# 61   0.094550    61    2.0         0.0         UNRATELTx
# 27   0.094169    27    5.0         1.0            IPNMAT
# 76   0.093542    76    5.0         0.0            HOANBS
# 178  0.093366   189    1.0         1.0           VIXCLSx
#
#                  SW MNEMONIC  \
# ID
# 38              Emp:Services
# 20                Output:Bus
# 36               Emp:Private
# 35               Emp:Nonfarm
# 21              Output:Manuf
# 58              LF Part Rate
# 34                 Capu Man.
# 191                      NaN
# 62            Urate:Age16-19
# 39                 Emp:Goods
# 68               U:Dur>27wks
# 59                Unemp Rate
# 22            IP:Total index
# 75                EmpHrs:mfg
# 180               Real CS_10
# 87                 Hstarts:W
# 24         IP:Consumer goods
# 30        IP:NonDur Cons God
# 40              Emp:DurGoods
# 74            EmpHrs:Bus Sec
# 6                 Investment
# 7                   FixedInv
# 73               Emp:SlackWk
# 8         Inv:Equip&Software
# 217                      NaN
# 49         Emp:Mining/NatRes
# 25              IP:Materials
# 63          Urate:Age>20 Men
# 177           Real HHW:FinSA
# 18               Disp-Income
# 45                 Emp:Infor
# 19                 Ouput:NFB
# 46              Emp:Bus Serv
# 65                U:Dur<5wks
# 26      IP:Dur gds materials
# 51                   Emp:Gov
# 37                   Emp:mfg
# 66              U:Dur5-14wks
# 56           Emp:Gov (Local)
# 89                 Ret. Sale
# 72            U:New Entrants
# 23         IP:Final products
# 41          Emp:Nondur Goods
# 5                Cons:NonDur
# 78                AWH Privat
# 52                Emp:Retail
# 61                  Urate_LT
# 27   IP:Nondur gds materials
# 76                EmpHrs:nfb
# 178                      VIX
#
#                                            DESCRIPTION  Group
# ID
# 38   All Employees: Service-Providing Industries (T...    3.0
# 20       Business Sector: Real Output (Index 2009=100)    1.0
# 36   All Employees: Total Private Industries (Thous...    3.0
# 35   All Employees: Total nonfarm (Thousands of Per...    3.0
# 21   Manufacturing Sector: Real Output (Index 2009=...    1.0
# 58   Civilian Labor Force Participation Rate (Percent)    3.0
# 34   Capacity Utilization: Manufacturing (SIC) (Per...    2.0
# 191  Shares of gross domestic product: Imports of g...    1.0
# 62        Unemployment Rate - 16 to 19 years (Percent)    3.0
# 39   All Employees: Goods-Producing Industries (Tho...    3.0
# 68   Number of Civilians Unemployed for 27 Weeks an...    3.0
# 59                Civilian Unemployment Rate (Percent)    3.0
# 22        Industrial Production Index (Index 2012=100)    2.0
# 75   Manufacturing Sector: Hours of All Persons (In...    3.0
# 180  S&P/Case-Shiller 10-City Composite Home Price ...    4.0
# 87   Housing Starts in West Census Region (Thousand...    4.0
# 24   Industrial Production: Consumer Goods (Index 2...    2.0
# 30   Industrial Production: Nondurable Consumer Goo...    2.0
# 40   All Employees: Durable goods (Thousands of Per...    3.0
# 74   Business Sector: Hours of All Persons (Index 2...    3.0
# 6    Real Gross Private Domestic Investment, 3 deci...    1.0
# 7    Real private fixed investment (Billions of Cha...    1.0
# 73   Employment Level - Part-Time for Economic Reas...    3.0
# 8    Real Gross Private Domestic Investment: Fixed ...    1.0
# 217  Consumer Motor Vehicle Loans Outstanding Owned...    9.0
# 49   All Employees: Mining and logging (Thousands o...    3.0
# 25   Industrial Production: Materials (Index 2012=100)    2.0
# 63   Unemployment Rate - 20 years and over, Men (Pe...    3.0
# 177  Real Total Financial Assets of Households and ...   10.0
# 18   Real Disposable Personal Income (Billions of C...    1.0
# 45   All Employees: Information Services (Thousands...    3.0
# 19   Nonfarm Business Sector: Real Output (Index 20...    1.0
# 46   All Employees: Professional & Business Service...    3.0
# 65   Number of Civilians Unemployed - Less Than 5 W...    3.0
# 26   Industrial Production: Durable Materials (Inde...    2.0
# 51    All Employees: Government (Thousands of Persons)    3.0
# 37   All Employees: Manufacturing (Thousands of Per...    3.0
# 66   Number of Civilians Unemployed for 5 to 14 Wee...    3.0
# 56   All Employees: Government: Local Government (T...    3.0
# 89   Real Retail and Food Services Sales (Millions ...    5.0
# 72   Unemployment Level - New Entrants (Thousands o...    3.0
# 23   Industrial Production: Final Products (Market ...    2.0
# 41   All Employees: Nondurable goods (Thousands of ...    3.0
# 5    Real Personal Consumption Expenditures: Nondur...    1.0
# 78   Average Weekly Hours Of Production And Nonsupe...    3.0
# 52   All Employees: Retail Trade (Thousands of Pers...    3.0
# 61   Unemployment Rate for more than 27 weeks (Perc...    3.0
# 27   Industrial Production: Nondurable Materials (I...    2.0
# 76   Nonfarm Business Sector: Hours of All Persons ...    3.0
# 178                         CBOE Volatility Index: VIX   13.0

# %% [markdown]
# ## Section 4

# %%
def RandomWalk(y):
    return ARIMA(y, order=(0,0,0)).fit()
def AutoRegressive(p, y):
    return ARIMA(y, order=(p,0,0)).fit()
def AutoRegressiveWithPC(p, y, pc):
    return ARIMA(y, order=(p,0,0), exog=pc).fit()
def VectorAutoregression(p, vars):
    return VAR(vars).fit(p)
def Standardize_Sample(sample):
    return (sample-sample.mean())/sample.std()
def Run_InSample_PCA(sample):
    return [p[0] for p in PCA(n_components=1).fit_transform(sample)]

raw_factors_notime = raw_factors.drop(['Time'], axis=1)
windows_size = 100
raw_standard_vars_till2019 = raw_standard_vars[(raw_standard_vars['Time'] < '2019-01-01') & (raw_factors['Time'] > '1960-07-10')].reset_index(drop=True)

forecasts = []
for i in range(len(raw_standard_vars_till2019)-windows_size):
    # calculate insample first principal component
    sample_factors = raw_factors_notime[i:101+i]
    sample_factors = Standardize_Sample(sample_factors)
    pc = Run_InSample_PCA(sample_factors)
    # create rolling windows
    arima_data = raw_standard_vars_till2019["diff_log_gdp"][i:100+i]
    var_data = raw_standard_vars_till2019[['diff_log_gdp', 'inflation', 'tspread']][i:100+i]
    # estimate models
    RW = RandomWalk(arima_data)
    AR4 = AutoRegressive(4, arima_data)
    VAR4 = VectorAutoregression(4, var_data)
    VAR1 = VectorAutoregression(1, var_data)
    AR4X = AutoRegressiveWithPC(4, arima_data, pc[:-1])

    forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]), 
                      float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# Out:
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /home/bob/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /home/bob/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /home/bob/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /home/bob/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /home/bob/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /home/bob/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/bob/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /home/bob/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /home/bob/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /home/bob/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /home/bob/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /home/bob/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /home/bob/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /home/bob/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /home/bob/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /home/bob/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /home/bob/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /home/bob/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /home/bob/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /home/bob/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# ...
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /home/bob/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/bob/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /home/bob/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /home/bob/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /home/bob/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/bob/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /home/bob/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /home/bob/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /home/bob/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /home/bob/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /home/bob/.local/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])
# /tmp/ipykernel_29576/2277152550.py:34: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   forecasts.append([float(RW.forecast()), float(AR4.forecast()), float(VAR4.forecast(var_data.values[-4:], 1)[0][0]),
# /tmp/ipykernel_29576/2277152550.py:35: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   float(VAR1.forecast(var_data.values[-1:], 1)[0][0]), float(AR4X.forecast(exog=pc[-1]))])

# %%
a = pd.DataFrame(forecasts, columns=['RW', 'AR4', 'VAR4', 'VAR1', 'AR4X'])

pd.concat([a, raw_standard_vars["diff_log_gdp"][101:235].reset_index(drop=True)], axis=1)

raw_standard_vars_till2019
# Out:
#           Time      GDPC1  PCECTPI   TB3MS    GS10   log_gdp   log_cpi  \
# 0   1960-06-30   3430.057   15.331  3.5400  4.5033  8.140332  2.729877
# 1   1960-09-30   3439.832   15.415  4.2300  4.5833  8.143178  2.735341
# 2   1960-12-30   3517.181   15.435  3.8733  4.4867  8.165415  2.736638
# 3   1961-03-30   3498.246   15.515  2.9933  4.2600  8.160017  2.741807
# 4   1961-06-30   3515.385   15.574  2.3600  3.8333  8.164904  2.745603
# ..         ...        ...      ...     ...     ...       ...       ...
# 230 2017-12-30  19398.343   99.524  0.5900  2.4433  9.872943  4.600399
# 231 2018-03-30  19506.949   99.724  0.8900  2.2633  9.878526  4.602406
# 232 2018-06-30  19660.766  100.076  1.0367  2.2433  9.886380  4.605930
# 233 2018-09-30  19882.352  100.676  1.2067  2.3700  9.897588  4.611907
# 234 2018-12-30  20044.077  101.380  1.5600  2.7600  9.905689  4.618876
#
#      inflation  tspread  diff_log_gdp
# 0     0.000000   0.9633      0.000000
# 1     0.005464   0.3533      0.002846
# 2     0.001297   0.6134      0.022237
# 3     0.005170   1.2667     -0.005398
# 4     0.003796   1.4733      0.004887
# ..         ...      ...           ...
# 230   0.005814   1.8533      0.004857
# 231   0.002008   1.3733      0.005583
# 232   0.003524   1.2066      0.007854
# 233   0.005978   1.1633      0.011207
# 234   0.006968   1.2000      0.008101
#
# [235 rows x 10 columns]
